# %% [markdown]
# <a href="https://colab.research.google.com/github/Nani2421/REAL-TIME-THEFT-DETECTION/blob/main/yolov10s_custom_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 72.6 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['WANDB_DISABLED'] = 'true'
print("W&B logging has been disabled.")
# Out:
# W&B logging has been disabled.

# %%
# !sed -i 's/torch.load(file, map_location="cpu")/torch.load(file, map_location="cpu", weights_only=False)/' /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py

# %%
# !wget -P '/content/drive/MyDrive/yolov10_weights' https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10s.pt
# Out:
# --2025-10-31 16:54:17--  https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10s.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Replace the placeholder path with the actual location of your zipped file.
# The dataset will be unzipped into a folder called 'yolov10_data' in the local Colab environment.
# !unzip -q '/content/drive/MyDrive/yolov10_training/archive.zip' -d '/content/yolov10_data'

# %%
# %%writefile /content/yolov10_data/data.yaml
# path: /content/yolov10_data
# train: train/images
# val: valid/images
# test: test/images
#
# nc: 2
# names: ['human', 'suspicion']
# Out:
# Overwriting /content/yolov10_data/data.yaml

# %%
# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model=/content/drive/MyDrive/yolov10_weights/yolov10s.pt \
    epochs=30 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10s_results \
    save_json=False
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Locate the path to your last saved checkpoint (last.pt)
LAST_CHECKPOINT_PATH = '/content/drive/MyDrive/yolov10_training_results/yolov10s_results/weights/last.pt'

# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model={LAST_CHECKPOINT_PATH} \
    epochs=30 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10s_final_run_resume \
    resume=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict \
    model=/content/drive/MyDrive/yolov10_training_results/yolov10s_results/weights/best.pt \
    source='/content/theif2.jpeg' \
    save=True
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv10s summary (fused): 106 layers, 7,218,774 parameters, 0 gradients, 21.4 GFLOPs
#
# image 1/1 /content/theif2.jpeg: 640x640 4 humans, 652.6ms
# Speed: 10.1ms preprocess, 652.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict \
    model=/content/drive/MyDrive/yolov10_training_results/yolov10s_results/weights/best.pt \
    source='/content/thief-stealing-handbag-27891534.webp' \
    save=True
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv10s summary (fused): 106 layers, 7,218,774 parameters, 0 gradients, 21.4 GFLOPs
#
# image 1/1 /content/thief-stealing-handbag-27891534.webp: 512x640 1 suspicion, 541.0ms
# Speed: 13.8ms preprocess, 541.0ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to /content/runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict \
    model=/content/drive/MyDrive/yolov10_training_results/yolov10s_results/weights/best.pt \
    source='/content/theif2.jpeg' \
    save=True
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv10s summary (fused): 106 layers, 7,218,774 parameters, 0 gradients, 21.4 GFLOPs
#
# image 1/1 /content/theif2.jpeg: 640x640 4 humans, 581.0ms
# Speed: 8.3ms preprocess, 581.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict \
    model=/content/drive/MyDrive/yolov10_training_results/yolov10s_results/weights/best.pt \
    source='/content/43960-Repairing-Potholes-1.webp' \
    save=True
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# YOLOv10s summary (fused): 106 layers, 7,218,774 parameters, 0 gradients, 21.4 GFLOPs
#
# image 1/1 /content/43960-Repairing-Potholes-1.webp: 384x640 1 human, 380.2ms
# Speed: 4.5ms preprocess, 380.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model=/content/drive/MyDrive/yolov10_training_results/yolov10s_results/weights/last.pt \
    epochs=30 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10s_results_continued \
    save_json=False
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model=/content/drive/MyDrive/yolov10_training_results/yolov10s_results_continued/weights/last.pt \
    epochs=40 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10s_results_continued_2 \
    save_json=False
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model=/content/drive/MyDrive/yolov10_training_results/yolov10s_results_continued_2/weights/last.pt \
    epochs=40 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10s_results_continued_2_) \
    save_json=False \
    resume = True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict \
    model=/content/drive/MyDrive/yolov10_training_results/yolov10s_results_continued_2/weights/best.pt \
    source='/content/theif_images.webp' \
    save=True
# Out:
# Ultralytics 8.3.223 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10s summary (fused): 106 layers, 7,218,774 parameters, 0 gradients, 21.4 GFLOPs
#
# image 1/1 /content/theif_images.webp: 448x640 1 human, 60.3ms
# Speed: 3.5ms preprocess, 60.3ms inference, 0.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
