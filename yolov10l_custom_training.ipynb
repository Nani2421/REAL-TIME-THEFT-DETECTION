# %% [markdown]
# <a href="https://colab.research.google.com/github/Nani2421/REAL-TIME-THEFT-DETECTION/blob/main/yolov10l_custom_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.226-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.226-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.226 ultralytics-thop-2.0.18

# %%
import os
os.environ['WANDB_DISABLED'] = 'true'
print("W&B logging has been disabled.")
# Out:
# W&B logging has been disabled.

# %%
# !sed -i 's/torch.load(file, map_location="cpu")/torch.load(file, map_location="cpu", weights_only=False)/' /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py

# %%
# !wget -P '/content/drive/MyDrive/yolov10_weights' https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10l.pt
# Out:
# --2025-11-04 08:23:44--  https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10m.pt
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/804788522/ef6276d5-333a-4f15-b994-b279b19d2683?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-11-04T09%3A03%3A20Z&rscd=attachment%3B+filename%3Dyolov10m.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-11-04T08%3A02%3A46Z&ske=2025-11-04T09%3A03%3A20Z&sks=b&skv=2018-11-09&sig=mKHWHWFlYoVf2kOAIpkplZvSmNiE%2FqWq5yyWW%2FNCF7U%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MjI0NjQyNSwibmJmIjoxNzYyMjQ0NjI1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.fGH2ChRsWsol7U7gtckbQkH0J3rIEycashFQx3XBLX8&response-content-disposition=attachment%3B%20filename%3Dyolov10m.pt&response-content-type=application%2Foctet-stream [following]
# --2025-11-04 08:23:45--  https://release-assets.githubusercontent.com/github-production-release-asset/804788522/ef6276d5-333a-4f15-b994-b279b19d2683?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-11-04T09%3A03%3A20Z&rscd=attachment%3B+filename%3Dyolov10m.pt&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-11-04T08%3A02%3A46Z&ske=2025-11-04T09%3A03%3A20Z&sks=b&skv=2018-11-09&sig=mKHWHWFlYoVf2kOAIpkplZvSmNiE%2FqWq5yyWW%2FNCF7U%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2MjI0NjQyNSwibmJmIjoxNzYyMjQ0NjI1LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.fGH2ChRsWsol7U7gtckbQkH0J3rIEycashFQx3XBLX8&response-content-disposition=attachment%3B%20filename%3Dyolov10m.pt&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66924323 (64M) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/yolov10_weights/yolov10m.pt.1’
#
# yolov10m.pt.1       100%[===================>]  63.82M  40.1MB/s    in 1.6s
#
# 2025-11-04 08:23:46 (40.1 MB/s) - ‘/content/drive/MyDrive/yolov10_weights/yolov10m.pt.1’ saved [66924323/66924323]

# %%
# Replace the placeholder path with the actual location of your zipped file.
# The dataset will be unzipped into a folder called 'yolov10_data' in the local Colab environment.
# !unzip -q '/content/drive/MyDrive/yolov10_training/archive.zip' -d '/content/yolov10_data'

# %%
# %%writefile /content/yolov10_data/data.yaml
# path: /content/yolov10_data
# train: train/images
# val: valid/images
# test: test/images
#
# nc: 2
# names: ['human', 'suspicion']
# Out:
# Overwriting /content/yolov10_data/data.yaml

# %%
# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model=/content/drive/MyDrive/yolov10_weights/yolov10l.pt \
    epochs=100 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10l_results \
    save_json=False
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov10l.pt to '/content/drive/MyDrive/yolov10_weights/yolov10l.pt': 100% ━━━━━━━━━━━━ 50.0MB 111.5MB/s 0.4s
# Ultralytics 8.3.224 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/yolov10_data/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/yolov10_weights/yolov10l.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov10l_results, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolov10_training_results, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/yolov10_training_results/yolov10l_results, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 22.7MB/s 0.0s
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1    137728  ultralytics.nn.modules.block.SCDown          [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#   8                  -1  3   1744384  ultralytics.nn.modules.block.C2fCIB          [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.PSA             [512, 512]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   1875456  ultralytics.nn.modules.block.C2fCIB          [768, 512, 3, True]
#  20                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  23        [16, 19, 22]  1   2825116  ultralytics.nn.modules.head.v10Detect        [2, [256, 512, 512]]
# YOLOv10l summary: 364 layers, 25,768,412 parameters, 25,768,396 gradients, 127.2 GFLOPs
#
# Transferred 1015/1027 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 96.0MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1261.3±836.0 MB/s, size: 49.5 KB)
# train: Scanning /content/yolov10_data/train/labels... 10420 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10420/10420 2.1Kit/s 5.0s
# train: /content/yolov10_data/train/images/rgb-0000036_jpg.rf.b26e50d81bd47b6347d091dae714d382.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000037_jpg.rf.4ffd9ec22b8f3b9fa1730cfe4a077f7c.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000038_jpg.rf.9c6707405f9ef1ec9cdef8492fbd6b69.jpg: 1 duplicate labels removed
# train: New cache created: /content/yolov10_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 924.5±592.2 MB/s, size: 28.8 KB)
# val: Scanning /content/yolov10_data/valid/labels... 1325 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1325/1325 1.3Kit/s 1.0s
# val: New cache created: /content/yolov10_data/valid/labels.cache
# Plotting labels to /content/drive/MyDrive/yolov10_training_results/yolov10l_results/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 167 weight(decay=0.0), 180 weight(decay=0.0005), 179 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/yolov10_training_results/yolov10l_results
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      12.6G          3      3.393      3.538         30        640: 100% ━━━━━━━━━━━━ 652/652 1.0it/s 10:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.1it/s 37.1s
#                    all       1325       3368      0.745      0.589      0.676      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      12.7G      2.969      2.578      3.433          9        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.7s
#                    all       1325       3368       0.73      0.552      0.629      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      12.8G       3.17      2.973      3.606         10        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.5it/s 27.1s
#                    all       1325       3368      0.587      0.492      0.499      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      12.8G      3.224      3.207       3.72         13        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:47
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368      0.672      0.554      0.597      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      12.4G      3.118      2.933      3.641         19        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368      0.733       0.59      0.667      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      12.5G      3.014      2.723      3.556         13        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:47
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.9s
#                    all       1325       3368      0.771      0.596      0.682      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      12.4G      2.942      2.519      3.482         19        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368      0.796       0.63      0.704      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      12.4G       2.87       2.42      3.432         38        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.7s
#                    all       1325       3368      0.819      0.645      0.731      0.419
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      12.5G      2.823      2.286      3.381         26        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.5s
#                    all       1325       3368      0.802      0.636       0.72      0.416
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      12.4G      2.786      2.208      3.361         18        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.7s
#                    all       1325       3368      0.857      0.653      0.742      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      12.5G      2.738      2.137      3.303         13        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 27.0s
#                    all       1325       3368      0.832      0.676      0.752      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      12.4G       2.71      2.079      3.282         15        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368      0.853       0.69      0.769      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      12.4G      2.672      1.993      3.278         22        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.7s
#                    all       1325       3368      0.849      0.699      0.778      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      12.4G      2.625      1.968      3.236         29        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:47
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368      0.886       0.69      0.786      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      12.4G      2.605       1.89      3.206         18        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.7s
#                    all       1325       3368      0.845      0.703      0.784      0.484
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      12.8G      2.576      1.845      3.169         18        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.5s
#                    all       1325       3368       0.88      0.711      0.799      0.492
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      12.4G      2.549      1.805      3.151          4        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.5s
#                    all       1325       3368      0.864      0.716      0.793      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      12.8G      2.519      1.765      3.125         29        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:47
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.5it/s 27.2s
#                    all       1325       3368      0.874      0.709      0.804      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      12.8G      2.509      1.737      3.113         10        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.7s
#                    all       1325       3368      0.849      0.737      0.804      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      12.4G      2.479      1.712      3.089         13        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 27.0s
#                    all       1325       3368      0.871      0.731      0.805      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      12.4G      2.447      1.686      3.069         26        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.5s
#                    all       1325       3368      0.871      0.727      0.804      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      12.4G      2.439      1.651      3.066         25        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.5it/s 27.1s
#                    all       1325       3368      0.865      0.741       0.81      0.514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      12.4G       2.42      1.642      3.058         15        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.5s
#                    all       1325       3368      0.871      0.747      0.817      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      12.4G      2.398      1.617       3.03          6        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.8s
#                    all       1325       3368      0.851      0.757      0.815      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      12.4G       2.38      1.567      3.021         10        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368      0.853      0.759      0.821      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      12.5G      2.363      1.546      3.016         24        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368       0.87      0.753      0.823      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      12.4G      2.336      1.524      2.985         10        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 27.0s
#                    all       1325       3368      0.885      0.759      0.824       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      12.4G      2.348      1.536      2.997         22        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.7s
#                    all       1325       3368      0.877      0.764       0.83      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      12.5G      2.302      1.481      2.959         14        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 27.1s
#                    all       1325       3368      0.873      0.771      0.827      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      12.5G      2.306      1.476      2.954         10        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.3s
#                    all       1325       3368      0.881      0.767       0.83      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      12.4G      2.273      1.443      2.944         77        640: 53% ━━━━━━────── 346/652 1.1it/s 5:10<4:35

# %%
# Locate the path to your last saved checkpoint (last.pt)
LAST_CHECKPOINT_PATH = '/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt'

# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model={LAST_CHECKPOINT_PATH} \
    resume=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/yolov10_data/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov10l_results, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolov10_training_results, rect=False, resume=/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/yolov10_training_results/yolov10l_results, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 67.1MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1    137728  ultralytics.nn.modules.block.SCDown          [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#   8                  -1  3   1744384  ultralytics.nn.modules.block.C2fCIB          [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.PSA             [512, 512]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   1875456  ultralytics.nn.modules.block.C2fCIB          [768, 512, 3, True]
#  20                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  23        [16, 19, 22]  1   2825116  ultralytics.nn.modules.head.v10Detect        [2, [256, 512, 512]]
# YOLOv10l summary: 364 layers, 25,768,412 parameters, 25,768,396 gradients, 127.2 GFLOPs
#
# Transferred 1027/1027 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 290.1MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1451.0±990.6 MB/s, size: 49.5 KB)
# train: Scanning /content/yolov10_data/train/labels... 10420 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10420/10420 2.4Kit/s 4.3s
# train: /content/yolov10_data/train/images/rgb-0000036_jpg.rf.b26e50d81bd47b6347d091dae714d382.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000037_jpg.rf.4ffd9ec22b8f3b9fa1730cfe4a077f7c.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000038_jpg.rf.9c6707405f9ef1ec9cdef8492fbd6b69.jpg: 1 duplicate labels removed
# train: New cache created: /content/yolov10_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 604.7±313.4 MB/s, size: 28.8 KB)
# val: Scanning /content/yolov10_data/valid/labels... 1325 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1325/1325 792.8it/s 1.7s
# val: New cache created: /content/yolov10_data/valid/labels.cache
# Plotting labels to /content/drive/MyDrive/yolov10_training_results/yolov10l_results/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 167 weight(decay=0.0), 180 weight(decay=0.0005), 179 bias(decay=0.0)
# Resuming training /content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt from epoch 31 to 100 total epochs
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/yolov10_training_results/yolov10l_results
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      12.6G      2.271      1.455      2.927         30        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 10:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.1it/s 37.1s
#                    all       1325       3368      0.896       0.75      0.832      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      12.8G      2.271       1.44      2.925          9        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.5s
#                    all       1325       3368      0.869      0.776      0.837      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      12.4G      2.244       1.41      2.912         10        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.7s
#                    all       1325       3368      0.871      0.769       0.83      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      12.5G      2.221      1.385      2.907         13        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:48
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368      0.882      0.764      0.834      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      12.4G      2.216      1.396       2.91         19        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:47
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.3s
#                    all       1325       3368      0.883      0.773      0.833      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      12.5G      2.193      1.375      2.881         13        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:38
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.0s
#                    all       1325       3368      0.901      0.766      0.829      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      12.4G      2.175      1.353      2.857         19        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.5s
#                    all       1325       3368      0.881      0.775      0.838      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      12.4G      2.157      1.341      2.843         38        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:45
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.2s
#                    all       1325       3368      0.883      0.783      0.838      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      12.4G      2.145      1.318      2.838         26        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:44
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368      0.874      0.777      0.828      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      12.4G      2.125      1.299      2.836         18        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.1s
#                    all       1325       3368      0.904      0.767      0.833      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      12.4G       2.12      1.293      2.812         13        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:43
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.8s
#                    all       1325       3368      0.902      0.769       0.84      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      12.4G      2.099      1.276      2.798         15        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:51
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368      0.884      0.788      0.844      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      12.4G      2.082      1.256      2.799         22        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368      0.905      0.783      0.846      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      12.4G      2.058      1.249      2.765         29        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.8s
#                    all       1325       3368      0.898       0.78      0.845      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      12.5G       2.05      1.236      2.749         18        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368       0.89      0.789      0.845      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      12.4G      2.027      1.222      2.747         18        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368      0.889      0.777      0.843      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      12.4G      2.014      1.201      2.732          4        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.7s
#                    all       1325       3368      0.919      0.763      0.843      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      12.4G      1.993      1.186      2.717         29        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:47
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.8s
#                    all       1325       3368      0.891      0.786      0.845       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      12.4G      1.984      1.176      2.705         10        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:47
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 26.6s
#                    all       1325       3368       0.89      0.785      0.848      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      12.4G       1.91      1.135      2.666         56        640: 10% ━─────────── 65/652 1.1it/s 1:00<8:43

# %%
# Locate the path to your last saved checkpoint (last.pt)
LAST_CHECKPOINT_PATH = '/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt'

# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model={LAST_CHECKPOINT_PATH} \
    resume=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/yolov10_data/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov10l_results, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolov10_training_results, rect=False, resume=/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/yolov10_training_results/yolov10l_results, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 126.9MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1    137728  ultralytics.nn.modules.block.SCDown          [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#   8                  -1  3   1744384  ultralytics.nn.modules.block.C2fCIB          [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.PSA             [512, 512]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   1875456  ultralytics.nn.modules.block.C2fCIB          [768, 512, 3, True]
#  20                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  23        [16, 19, 22]  1   2825116  ultralytics.nn.modules.head.v10Detect        [2, [256, 512, 512]]
# YOLOv10l summary: 364 layers, 25,768,412 parameters, 25,768,396 gradients, 127.2 GFLOPs
#
# Transferred 1027/1027 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 327.9MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1257.7±795.5 MB/s, size: 49.5 KB)
# train: Scanning /content/yolov10_data/train/labels... 10420 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10420/10420 2.5Kit/s 4.1s
# train: /content/yolov10_data/train/images/rgb-0000036_jpg.rf.b26e50d81bd47b6347d091dae714d382.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000037_jpg.rf.4ffd9ec22b8f3b9fa1730cfe4a077f7c.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000038_jpg.rf.9c6707405f9ef1ec9cdef8492fbd6b69.jpg: 1 duplicate labels removed
# train: New cache created: /content/yolov10_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 792.6±283.5 MB/s, size: 28.8 KB)
# val: Scanning /content/yolov10_data/valid/labels... 1325 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1325/1325 1.1Kit/s 1.2s
# val: New cache created: /content/yolov10_data/valid/labels.cache
# Plotting labels to /content/drive/MyDrive/yolov10_training_results/yolov10l_results/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 167 weight(decay=0.0), 180 weight(decay=0.0005), 179 bias(decay=0.0)
# Resuming training /content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt from epoch 50 to 100 total epochs
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/yolov10_training_results/yolov10l_results
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      12.6G      1.924      1.137       2.66         30        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.2it/s 34.1s
#                    all       1325       3368      0.898      0.777      0.844      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      12.8G      1.934      1.144      2.666          9        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 25.4s
#                    all       1325       3368      0.884      0.792      0.846      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      12.4G      1.913      1.116      2.667         10        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 25.4s
#                    all       1325       3368      0.891      0.789      0.853      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      12.8G      1.891      1.105      2.659         13        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 25.4s
#                    all       1325       3368       0.89      0.789      0.851      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      12.4G      1.884      1.117      2.644         19        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.7s
#                    all       1325       3368      0.897      0.781      0.846      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      12.5G      1.866      1.087      2.631         13        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.5s
#                    all       1325       3368      0.899      0.786      0.847      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      12.4G      1.845      1.081      2.609         19        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 25.3s
#                    all       1325       3368      0.902      0.781       0.85      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      12.4G      1.834      1.067      2.596         38        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.5s
#                    all       1325       3368      0.905      0.785      0.849      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      12.4G      1.818      1.052      2.578         26        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:24
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.5s
#                    all       1325       3368      0.897      0.786      0.851      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      12.4G      1.804      1.039      2.572         18        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:23
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.5s
#                    all       1325       3368      0.899      0.787      0.849      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      12.5G      1.796       1.05      2.567         13        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 25.5s
#                    all       1325       3368      0.902      0.787      0.849      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      12.4G      1.781       1.02      2.548         15        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:22
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.8s
#                    all       1325       3368      0.901       0.79      0.851      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      12.4G      1.795      1.028      2.587         85        640: 6% ╸─────────── 36/652 1.1it/s 32.5s<9:02

# %%
# Locate the path to your last saved checkpoint (last.pt)
LAST_CHECKPOINT_PATH = '/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt'

# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model={LAST_CHECKPOINT_PATH} \
    resume=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/yolov10_data/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov10l_results, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolov10_training_results, rect=False, resume=/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 135.1MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1    137728  ultralytics.nn.modules.block.SCDown          [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#   8                  -1  3   1744384  ultralytics.nn.modules.block.C2fCIB          [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.PSA             [512, 512]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   1875456  ultralytics.nn.modules.block.C2fCIB          [768, 512, 3, True]
#  20                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  23        [16, 19, 22]  1   2825116  ultralytics.nn.modules.head.v10Detect        [2, [256, 512, 512]]
# YOLOv10l summary: 364 layers, 25,768,412 parameters, 25,768,396 gradients, 127.2 GFLOPs
#
# Transferred 1027/1027 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 182.7MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1091.3±550.3 MB/s, size: 49.5 KB)
# train: Scanning /content/yolov10_data/train/labels... 10420 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10420/10420 2.3Kit/s 4.5s
# train: /content/yolov10_data/train/images/rgb-0000036_jpg.rf.b26e50d81bd47b6347d091dae714d382.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000037_jpg.rf.4ffd9ec22b8f3b9fa1730cfe4a077f7c.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000038_jpg.rf.9c6707405f9ef1ec9cdef8492fbd6b69.jpg: 1 duplicate labels removed
# train: New cache created: /content/yolov10_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 754.3±353.7 MB/s, size: 28.8 KB)
# val: Scanning /content/yolov10_data/valid/labels... 1325 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1325/1325 1.2Kit/s 1.1s
# val: New cache created: /content/yolov10_data/valid/labels.cache
# Plotting labels to /content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 167 weight(decay=0.0), 180 weight(decay=0.0005), 179 bias(decay=0.0)
# Resuming training /content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt from epoch 62 to 100 total epochs
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      12.6G      1.664     0.9539      2.469         30        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.2it/s 34.6s
#                    all       1325       3368      0.906      0.787      0.847      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      12.8G      1.683     0.9605      2.486          9        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 25.3s
#                    all       1325       3368      0.906       0.79      0.849      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      12.4G      1.659     0.9435      2.474         10        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 25.0s
#                    all       1325       3368      0.901      0.794      0.851      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      12.5G      1.643     0.9265      2.471         13        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:19
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 25.0s
#                    all       1325       3368      0.901       0.79       0.85      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      12.4G      1.633     0.9323      2.456         19        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:18
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 25.0s
#                    all       1325       3368      0.914      0.785      0.851      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      12.4G      1.597     0.9144      2.436         80        640: 31% ━━━╸──────── 203/652 1.2it/s 2:55<6:17

# %%
# Locate the path to your last saved checkpoint (last.pt)
LAST_CHECKPOINT_PATH = '/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt'

# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model={LAST_CHECKPOINT_PATH} \
    resume=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/yolov10_data/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov10l_results, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolov10_training_results, rect=False, resume=/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 86.4MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1    137728  ultralytics.nn.modules.block.SCDown          [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#   8                  -1  3   1744384  ultralytics.nn.modules.block.C2fCIB          [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.PSA             [512, 512]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   1875456  ultralytics.nn.modules.block.C2fCIB          [768, 512, 3, True]
#  20                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  23        [16, 19, 22]  1   2825116  ultralytics.nn.modules.head.v10Detect        [2, [256, 512, 512]]
# YOLOv10l summary: 364 layers, 25,768,412 parameters, 25,768,396 gradients, 127.2 GFLOPs
#
# Transferred 1027/1027 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 233.1MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1392.0±891.3 MB/s, size: 49.5 KB)
# train: Scanning /content/yolov10_data/train/labels... 10420 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10420/10420 2.6Kit/s 4.0s
# train: /content/yolov10_data/train/images/rgb-0000036_jpg.rf.b26e50d81bd47b6347d091dae714d382.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000037_jpg.rf.4ffd9ec22b8f3b9fa1730cfe4a077f7c.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000038_jpg.rf.9c6707405f9ef1ec9cdef8492fbd6b69.jpg: 1 duplicate labels removed
# train: New cache created: /content/yolov10_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 727.0±364.1 MB/s, size: 28.8 KB)
# val: Scanning /content/yolov10_data/valid/labels... 1325 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1325/1325 1.1Kit/s 1.2s
# val: New cache created: /content/yolov10_data/valid/labels.cache
# Plotting labels to /content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 167 weight(decay=0.0), 180 weight(decay=0.0005), 179 bias(decay=0.0)
# Resuming training /content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt from epoch 68 to 100 total epochs
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      12.6G      1.451     0.8196      2.323         30        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:21
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.2it/s 33.9s
#                    all       1325       3368      0.908      0.789      0.849      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      12.8G      1.472     0.8286      2.332          9        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.3s
#                    all       1325       3368      0.913      0.783      0.849      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      12.4G      1.466     0.8228      2.333         10        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.3s
#                    all       1325       3368      0.912      0.788      0.849       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      12.8G      1.474     0.8254      2.349         13        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.3s
#                    all       1325       3368      0.923      0.774      0.848      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      12.8G      1.497     0.8464      2.362         19        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.6s
#                    all       1325       3368      0.911      0.779      0.846      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      12.8G      1.521     0.8673      2.379         13        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.4s
#                    all       1325       3368      0.909      0.784      0.846      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      12.8G      1.554     0.8809      2.387         19        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.7s
#                    all       1325       3368      0.916       0.78      0.848      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      12.8G      1.538       0.87      2.379         38        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.4s
#                    all       1325       3368      0.915      0.781       0.85      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      12.4G      1.521     0.8607      2.367         26        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.6s
#                    all       1325       3368      0.907      0.786      0.851      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      12.4G      1.516      0.855      2.374         18        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.3s
#                    all       1325       3368      0.904      0.788      0.851      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      12.4G      1.528     0.8649      2.362         13        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.4s
#                    all       1325       3368      0.896      0.797      0.852      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      12.4G      1.547     0.8765      2.371         15        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.4s
#                    all       1325       3368      0.902      0.792      0.852      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      12.8G      1.566     0.8742      2.403         22        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.3s
#                    all       1325       3368      0.918      0.784      0.852      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      12.8G      1.543     0.8682       2.38         29        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.4s
#                    all       1325       3368      0.919      0.785      0.851      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      12.4G      1.539     0.8649      2.363         18        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:08
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.4s
#                    all       1325       3368      0.915      0.783       0.85      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      12.4G      1.512     0.8498      2.354         18        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.6s
#                    all       1325       3368      0.917      0.785      0.851      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      12.4G        1.5     0.8422      2.345          4        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.5s
#                    all       1325       3368      0.914      0.788       0.85      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      12.4G      1.476     0.8253      2.336         29        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.3s
#                    all       1325       3368      0.913       0.79      0.851      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      12.4G      1.481     0.8351      2.331         10        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.4s
#                    all       1325       3368      0.915      0.789      0.851      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      12.5G      1.511     0.8569      2.345         13        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.3s
#                    all       1325       3368      0.911      0.791       0.85      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      12.4G      1.481       0.84      2.328         26        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.4s
#                    all       1325       3368      0.919      0.785      0.852      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      12.5G      1.474     0.8251      2.328         25        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.3s
#                    all       1325       3368      0.917      0.786      0.851      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      12.5G      1.466     0.8363       2.33         15        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.4s
#                    all       1325       3368       0.91       0.79      0.851      0.564
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      12.4G      1.333     0.6288      2.219         11        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.4s
#                    all       1325       3368      0.921      0.785      0.851      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      12.3G       1.29     0.6003      2.188         33        640: 92% ━━━━━━━━━━━─ 599/652 1.2it/s 8:23<46.0s

# %%
# Locate the path to your last saved checkpoint (last.pt)
LAST_CHECKPOINT_PATH = '/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt'

# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model={LAST_CHECKPOINT_PATH} \
    resume=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/yolov10_data/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov10l_results, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolov10_training_results, rect=False, resume=/content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 27.6MB/s 0.0s
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1    137728  ultralytics.nn.modules.block.SCDown          [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#   8                  -1  3   1744384  ultralytics.nn.modules.block.C2fCIB          [512, 512, 3, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.PSA             [512, 512]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   1247744  ultralytics.nn.modules.block.C2f             [768, 256, 3]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   1875456  ultralytics.nn.modules.block.C2fCIB          [768, 512, 3, True]
#  20                  -1  1    268800  ultralytics.nn.modules.block.SCDown          [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  3   2006528  ultralytics.nn.modules.block.C2fCIB          [1024, 512, 3, True]
#  23        [16, 19, 22]  1   2825116  ultralytics.nn.modules.head.v10Detect        [2, [256, 512, 512]]
# YOLOv10l summary: 364 layers, 25,768,412 parameters, 25,768,396 gradients, 127.2 GFLOPs
#
# Transferred 1027/1027 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 113.0MB/s 0.0s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1352.9±837.9 MB/s, size: 49.5 KB)
# train: Scanning /content/yolov10_data/train/labels... 10420 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10420/10420 2.5Kit/s 4.2s
# train: /content/yolov10_data/train/images/rgb-0000036_jpg.rf.b26e50d81bd47b6347d091dae714d382.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000037_jpg.rf.4ffd9ec22b8f3b9fa1730cfe4a077f7c.jpg: 1 duplicate labels removed
# train: /content/yolov10_data/train/images/rgb-0000038_jpg.rf.9c6707405f9ef1ec9cdef8492fbd6b69.jpg: 1 duplicate labels removed
# train: New cache created: /content/yolov10_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 798.7±466.4 MB/s, size: 28.8 KB)
# val: Scanning /content/yolov10_data/valid/labels... 1325 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1325/1325 745.9it/s 1.8s
# val: New cache created: /content/yolov10_data/valid/labels.cache
# Plotting labels to /content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 167 weight(decay=0.0), 180 weight(decay=0.0005), 179 bias(decay=0.0)
# Resuming training /content/drive/MyDrive/yolov10_training_results/yolov10l_results/weights/last.pt from epoch 92 to 100 total epochs
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      12.6G      1.201       0.68      2.152         30        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:40
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.2it/s 35.1s
#                    all       1325       3368      0.919      0.783       0.85      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      12.8G      1.211     0.6768      2.152          9        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.5s
#                    all       1325       3368      0.922      0.782       0.85      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      12.4G        1.2     0.6664      2.154         10        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.5s
#                    all       1325       3368      0.921      0.782       0.85      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      12.5G      1.191     0.6571      2.157         13        640: 100% ━━━━━━━━━━━━ 652/652 1.1it/s 9:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.7s
#                    all       1325       3368      0.921       0.78      0.851      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      12.4G      1.195     0.6661      2.153         19        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.5s
#                    all       1325       3368      0.911      0.785       0.85      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      12.5G      1.202     0.6692      2.163         13        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.6s
#                    all       1325       3368      0.912      0.785       0.85      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      12.4G       1.21     0.6759      2.161         19        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.7s
#                    all       1325       3368      0.922      0.779      0.849      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      12.4G      1.199     0.6698      2.154         38        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.7s
#                    all       1325       3368       0.92      0.781      0.849      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      12.4G      1.185      0.664       2.15         26        640: 100% ━━━━━━━━━━━━ 652/652 1.2it/s 9:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.6it/s 25.6s
#                    all       1325       3368      0.921      0.782       0.85      0.563
#
# 9 epochs completed in 1.490 hours.
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results/weights/last.pt, 52.2MB
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results/weights/best.pt, 52.2MB
#
# Validating /content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results/weights/best.pt...
# Ultralytics 8.3.226 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10l summary (fused): 174 layers, 24,310,870 parameters, 0 gradients, 120.0 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 42/42 1.7it/s 24.7s
#                    all       1325       3368      0.898      0.787      0.849      0.569
#                  human        853       2130      0.921      0.822       0.89      0.628
#              suspicion        701       1238      0.875      0.753      0.809       0.51
# Speed: 0.2ms preprocess, 15.1ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/1CsXOotbPGH254YzbPsrKcGOqdRrOTarN/yolov10_training_results/yolov10l_results
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !yolo detect predict \
    model=/content/drive/MyDrive/yolov10_training_results/yolov10m_results_continued/weights/best.pt \
    source='/content/thief-stealing-handbag-27891534.webp' \
    save=True
