# %% [markdown]
# <a href="https://colab.research.google.com/github/Nani2421/REAL-TIME-THEFT-DETECTION/blob/main/yolov10m_custom_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 11.4 MB/s eta 0:00:00
# ...

# %%
import os
os.environ['WANDB_DISABLED'] = 'true'
print("W&B logging has been disabled.")
# Out:
# W&B logging has been disabled.

# %%
# !sed -i 's/torch.load(file, map_location="cpu")/torch.load(file, map_location="cpu", weights_only=False)/' /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py

# %%
# !wget -P '/content/drive/MyDrive/yolov10_weights' https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10m.pt
# Out:
# --2025-10-05 13:42:08--  https://github.com/THU-MIG/yolov10/releases/download/v1.1/yolov10m.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Replace the placeholder path with the actual location of your zipped file.
# The dataset will be unzipped into a folder called 'yolov10_data' in the local Colab environment.
# !unzip -q '/content/drive/MyDrive/yolov10_training/archive.zip' -d '/content/yolov10_data'

# %%
# %%writefile /content/yolov10_data/data.yaml
# path: /content/yolov10_data
# train: train/images
# val: valid/images
# test: test/images
#
# nc: 2
# names: ['human', 'suspicion']
# Out:
# Overwriting /content/yolov10_data/data.yaml

# %%
# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model=/content/drive/MyDrive/yolov10_weights/yolov10m.pt \
    epochs=30 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10m_results \
    save_json=False
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Locate the path to your last saved checkpoint (last.pt)
LAST_CHECKPOINT_PATH = '/content/drive/MyDrive/yolov10_training_results/yolov10m_results/weights/last.pt'

# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model={LAST_CHECKPOINT_PATH} \
    epochs=100 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10m_results \
    resume=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.205 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Locate the path to your last saved checkpoint (last.pt)
LAST_CHECKPOINT_PATH = '/content/drive/MyDrive/yolov10_training_results/yolov10m_results/weights/last.pt'

# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model={LAST_CHECKPOINT_PATH} \
    epochs=70 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10m_results_continued
# Out:
# Ultralytics 8.3.205 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Locate the path to your last saved checkpoint (last.pt)
LAST_CHECKPOINT_PATH = '/content/drive/MyDrive/yolov10_training_results/yolov10m_results_continued/weights/last.pt'

# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model={LAST_CHECKPOINT_PATH} \
    epochs=70 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10m_results_continued \
    resume = True
# Out:
# Ultralytics 8.3.205 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Locate the path to your last saved checkpoint (last.pt)
LAST_CHECKPOINT_PATH = '/content/drive/MyDrive/yolov10_training_results/yolov10m_results_continued/weights/last.pt'

# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model={LAST_CHECKPOINT_PATH} \
    epochs=70 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10m_results_continued \
    resume = True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.206 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Locate the path to your last saved checkpoint (last.pt)
LAST_CHECKPOINT_PATH = '/content/drive/MyDrive/yolov10_training_results/yolov10m_results_continued/weights/last.pt'

# !yolo detect train \
    data=/content/yolov10_data/data.yaml \
    model={LAST_CHECKPOINT_PATH} \
    epochs=70 \
    imgsz=640 \
    project=/content/drive/MyDrive/yolov10_training_results \
    name=yolov10m_results_continued \
    resume = True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.207 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict \
    model=/content/drive/MyDrive/yolov10_training_results/yolov10m_results_continued/weights/last.pt \
    source='/content/ChatGPT Image Nov 4, 2025, 03_30_45 PM.png' \
    save=True
